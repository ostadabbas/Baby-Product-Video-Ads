# %% [markdown]
# # This notebook applies PCA to audio feature selection

# %%
import pickle
import os
import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.api import OLS
import statsmodels.api as sm
import statsmodels.stats as sts
from scipy import stats
import statsmodels.stats.api as sms
import re

import datetime
date = datetime.datetime.now()
date = date.strftime("%Y.%m.%d")
np.random.seed(0)

def stdz(series: pd.Series):
    """Standardize the given pandas Series"""
    return (series - series.mean())/series.std()
def unitstdz(series:pd.Series):
    return (series - series.min())/(series.max()-series.min())

from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# # read data

# %%
rating = pd.read_excel('eyetracking-coordinates-imname.xlsx', sheet_name='video-based')

# %%
rating.columns
# Out:
# Index(['VideoNumber', 'GroupN(1=low(1-3),2=neutral(4-6),3=high(7-10))',
#        'PrefereneMean', 'PurchaseDesireMean', 'NarrativeInterityMean',
#        'EmpathyMean', 'TotalTime(S)', 'ShotNumber', 'ShotMean',
#        'Shotvariance'],
#       dtype='object')

# %%
rating.drop('Shotvariance',axis=1,inplace=True)

# %%
rating.head()
# Out:
#    VideoNumber  GroupN(1=low(1-3),2=neutral(4-6),3=high(7-10))  PrefereneMean  \
# 0            1                                               2       5.957447
# 1            2                                               2       5.000000
# 2            3                                               1       3.000000
# 3            4                                               3       7.111111
# 4            5                                               1       3.666667
#
#    PurchaseDesireMean  NarrativeInterityMean  EmpathyMean  TotalTime(S)  \
# 0            5.553191               5.085106     5.255319            33
# 1            4.000000               5.000000     6.333333            84
# 2            1.777778               5.555556     2.777778            31
# 3            6.777778               4.666667     6.777778            34
# 4            2.333333               5.833333     2.833333            32
#
#    ShotNumber  ShotMean
# 0           8  4.125000
# 1           9  9.333333
# 2          10  3.100000
# 3          17  2.000000
# 4          12  2.666667

# %%
def split_ad_id(ad_id):
    if '+' in ad_id[0:5]:
        return ad_id.split('+')[0]
    elif '-' in ad_id[0:5]:
        return ad_id.split('-')[0]
    else:
        return ad_id  # if neither '+' nor '-' is present, return the original ad_id

# %%
def lowercase_columns(df):
    df.columns = df.columns.str.lower()
    return df

# Read the first file and convert column names to lowercase
features = pd.read_csv('audio_features.csv')
features = lowercase_columns(features)
features = lowercase_columns(features)
features['VideoNumber'] = features['filename'].apply(split_ad_id)

# %%
features.columns
# Out:
# Index(['filename', 'duration', 'rms_mean', 'rms_std', 'rms_max', 'zcr_mean',
#        'zcr_std', 'spectral_centroid_mean', 'spectral_centroid_std',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_std', 'pitch_mean',
#        'pitch_std', 'mfcc_1_mean', 'mfcc_1_std', 'mfcc_2_mean', 'mfcc_2_std',
#        'mfcc_3_mean', 'mfcc_3_std', 'mfcc_4_mean', 'mfcc_4_std', 'mfcc_5_mean',
#        'mfcc_5_std', 'mfcc_6_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std',
#        'mfcc_8_mean', 'mfcc_8_std', 'mfcc_9_mean', 'mfcc_9_std',
#        'mfcc_10_mean', 'mfcc_10_std', 'mfcc_11_mean', 'mfcc_11_std',
#        'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean', 'mfcc_13_std',
#        'chroma_1_mean', 'chroma_1_std', 'chroma_2_mean', 'chroma_2_std',
#        'chroma_3_mean', 'chroma_3_std', 'chroma_4_mean', 'chroma_4_std',
#        'chroma_5_mean', 'chroma_5_std', 'chroma_6_mean', 'chroma_6_std',
#        'chroma_7_mean', 'chroma_7_std', 'chroma_8_mean', 'chroma_8_std',
#        'chroma_9_mean', 'chroma_9_std', 'chroma_10_mean', 'chroma_10_std',
#        'chroma_11_mean', 'chroma_11_std', 'chroma_12_mean', 'chroma_12_std',
#        'mel_spectrogram_mean', 'mel_spectrogram_std', 'VideoNumber'],
#       dtype='object')

# %%
features.tail()
# Out:
#                                               filename  duration  rms_mean  \
# 106                  95+The Promise of Similac (1).mp3     30.09  0.034744
# 107                      96+The Promise of Similac.mp3     15.07  0.033668
# 108  97+The Wonder of Baby  SMA® PRO Follow on Milk...     30.07  0.041637
# 109            98+Unibale Baby formula- Babyactiv8.mp3     30.07  0.035107
# 110  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
#
#       rms_std   rms_max  zcr_mean   zcr_std  spectral_centroid_mean  \
# 106  0.020984  0.099656  0.057304  0.079066             2281.776720
# 107  0.021797  0.098135  0.054048  0.079519             2098.451675
# 108  0.025440  0.116514  0.059701  0.069674             2458.209766
# 109  0.016796  0.090101  0.062981  0.063250             3083.946332
# 110  0.030880  0.157743  0.033685  0.021835             1380.853342
#
#      spectral_centroid_std  spectral_bandwidth_mean  ...  chroma_9_std  \
# 106            1885.872308              2608.298671  ...      0.291850
# 107            1915.333550              2465.571943  ...      0.261239
# 108            1609.758632              2949.133262  ...      0.290666
# 109            1510.506873              3439.121626  ...      0.285418
# 110             525.336408              1634.023818  ...      0.275557
#
#      chroma_10_mean  chroma_10_std  chroma_11_mean  chroma_11_std  \
# 106        0.353905       0.304546        0.423634       0.346395
# 107        0.321404       0.262159        0.454804       0.355037
# 108        0.517180       0.306825        0.589720       0.308117
# 109        0.474783       0.308618        0.456359       0.284647
# 110        0.490710       0.319638        0.545004       0.312044
#
#      chroma_12_mean  chroma_12_std  mel_spectrogram_mean  mel_spectrogram_std  \
# 106        0.348586       0.283656              0.295351             2.807308
# 107        0.380009       0.291834              0.287847             2.636283
# 108        0.502666       0.266747              0.443862             3.298790
# 109        0.527332       0.329419              0.280122             2.320226
# 110        0.478621       0.285852              0.608709             4.155523
#
#      VideoNumber
# 106           95
# 107           96
# 108           97
# 109           98
# 110           99
#
# [5 rows x 66 columns]

# %%
features['VideoNumber'] = features['VideoNumber'].astype(np.int64)

# %%
data = features.merge(rating, on='VideoNumber', how='inner')

# %% [raw]
# features['filename'].unique()

# %% [raw]
# dispersion['ad_id'].unique()

# %%
data['ad_id'] = data['filename'].apply(lambda x: x.replace('.mp3', '.mp4'))

# %%
for col in data.columns:
    if data[col].isna().any():
        print(col)

# %%
data = data.dropna(how='any')
data = data.replace([np.inf, -np.inf], np.nan).dropna()

# %%
features = ['rms_mean', 'rms_std', 'rms_max', 'zcr_mean', 'zcr_std', 'spectral_centroid_mean', 'spectral_centroid_std', 'spectral_bandwidth_mean',
            'spectral_bandwidth_std', 'pitch_mean', 'pitch_std', 'mfcc_1_mean', 'mfcc_1_std', 'mfcc_2_mean', 'mfcc_2_std', 'mfcc_3_mean', 'mfcc_3_std',
            'mfcc_4_mean', 'mfcc_4_std', 'mfcc_5_mean', 'mfcc_5_std', 'mfcc_6_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std', 'mfcc_8_mean', 'mfcc_8_std', 
            'mfcc_9_mean', 'mfcc_9_std', 'mfcc_10_mean', 'mfcc_10_std', 'mfcc_11_mean', 'mfcc_11_std', 'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean', 
            'mfcc_13_std', 'chroma_1_mean', 'chroma_1_std', 'chroma_2_mean', 'chroma_2_std', 'chroma_3_mean', 'chroma_3_std', 'chroma_4_mean', 'chroma_4_std',
            'chroma_5_mean', 'chroma_5_std', 'chroma_6_mean', 'chroma_6_std', 'chroma_7_mean', 'chroma_7_std', 'chroma_8_mean', 'chroma_8_std', 'chroma_9_mean',
            'chroma_9_std', 'chroma_10_mean', 'chroma_10_std', 'chroma_11_mean', 'chroma_11_std', 'chroma_12_mean', 'chroma_12_std', 'mel_spectrogram_mean', 
            'mel_spectrogram_std']

# %%
len(features)
# Out:
# 63

# %% [markdown]
# # dispersion

# %%
data.head()
# Out:
#                                             filename   duration  rms_mean  \
# 0                            1+90 Years Crafting.mp3  32.299977  0.067268
# 1                         10+Aptamil Advert 2021.mp3  30.140000  0.074573
# 2  100+Vintage Carnation infant formula commercia...  68.430000  0.050167
# 3                        101+Welcome To Kendamil.mp3  60.300000  0.063147
# 4            102+Welcome to the Kendamil family!.mp3  60.910000  0.065595
#
#     rms_std   rms_max  zcr_mean   zcr_std  spectral_centroid_mean  \
# 0  0.042547  0.186023  0.067580  0.083763             3061.162958
# 1  0.049418  0.259800  0.065928  0.095349             2523.259214
# 2  0.053738  0.295545  0.041340  0.041643             1852.533373
# 3  0.049256  0.265595  0.044595  0.055455             2108.228601
# 4  0.049353  0.252705  0.045361  0.058613             2140.927916
#
#    spectral_centroid_std  spectral_bandwidth_mean  ...  VideoNumber  \
# 0            2014.217722              3452.305987  ...            1
# 1            1908.065955              3028.894412  ...           10
# 2            1134.412981              2447.992161  ...          100
# 3            1422.951136              2701.332497  ...          101
# 4            1467.060556              2743.072238  ...          102
#
#    GroupN(1=low(1-3),2=neutral(4-6),3=high(7-10))  PrefereneMean  \
# 0                                               2       5.957447
# 1                                               2       4.166667
# 2                                               1       3.333333
# 3                                               2       4.176471
# 4                                               2       4.285714
#
#    PurchaseDesireMean  NarrativeInterityMean  EmpathyMean  TotalTime(S)  \
# 0            5.553191               5.085106     5.255319            33
# 1            4.000000               5.666667     3.333333            31
# 2            3.000000               6.666667     2.333333            69
# 3            3.588235               5.166667     3.388889            61
# 4            3.857143               5.000000     2.857143            61
#
#    ShotNumber  ShotMean                                              ad_id
# 0           8  4.125000                            1+90 Years Crafting.mp4
# 1          14  2.214286                         10+Aptamil Advert 2021.mp4
# 2          26  2.653846  100+Vintage Carnation infant formula commercia...
# 3          14  4.357143                        101+Welcome To Kendamil.mp4
# 4          19  3.210526            102+Welcome to the Kendamil family!.mp4
#
# [5 rows x 75 columns]

# %%
def extract_video_number(filename):
    match = re.match(r'(\d+)[+-]', filename)
    return match.group(1) if match else None

# %%
dispersion1 = pd.read_json('dispersion_measure0629.json', lines=True)

# %%
dispersion1.columns
# Out:
# Index(['ad_id', 'id', 'std_x', 'std_y', 'combined_std', 'convex_hull_area',
#        'convex_hull_area_shapely', 'mean_euclidean_distance', 'VideoNumber'],
#       dtype='object')

# %%
dispersion1['VideoNumber'] = dispersion1['ad_id'].apply(extract_video_number)
data['VideoNumber'] = data['VideoNumber'].astype(int)
dispersion1['VideoNumber'] = dispersion1['VideoNumber'].astype(int)
data = data.merge(dispersion1[['id', 'std_x', 'std_y', 'combined_std', 'convex_hull_area',
       'convex_hull_area_shapely', 'mean_euclidean_distance', 'VideoNumber']], on='VideoNumber')

# %%
#data = data.merge(dispersion[['ad_id','mean_distance','std_distance']], on='ad_id')

# %%
data.head(10)
# Out:
#                      filename   duration  rms_mean   rms_std   rms_max  \
# 0     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 1     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 2     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 3     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 4     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 5     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 6     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 7     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 8     1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023
# 9  10+Aptamil Advert 2021.mp3  30.140000  0.074573  0.049418  0.259800
#
#    zcr_mean   zcr_std  spectral_centroid_mean  spectral_centroid_std  \
# 0  0.067580  0.083763             3061.162958            2014.217722
# 1  0.067580  0.083763             3061.162958            2014.217722
# 2  0.067580  0.083763             3061.162958            2014.217722
# 3  0.067580  0.083763             3061.162958            2014.217722
# 4  0.067580  0.083763             3061.162958            2014.217722
# 5  0.067580  0.083763             3061.162958            2014.217722
# 6  0.067580  0.083763             3061.162958            2014.217722
# 7  0.067580  0.083763             3061.162958            2014.217722
# 8  0.067580  0.083763             3061.162958            2014.217722
# 9  0.065928  0.095349             2523.259214            1908.065955
#
#    spectral_bandwidth_mean  ...  ShotNumber  ShotMean  \
# 0              3452.305987  ...           8  4.125000
# 1              3452.305987  ...           8  4.125000
# 2              3452.305987  ...           8  4.125000
# 3              3452.305987  ...           8  4.125000
# 4              3452.305987  ...           8  4.125000
# 5              3452.305987  ...           8  4.125000
# 6              3452.305987  ...           8  4.125000
# 7              3452.305987  ...           8  4.125000
# 8              3452.305987  ...           8  4.125000
# 9              3028.894412  ...          14  2.214286
#
#                         ad_id                 id     std_x     std_y  \
# 0     1+90 Years Crafting.mp4  R_2qFdJq0jnOo6gpt  0.049059  0.132776
# 1     1+90 Years Crafting.mp4  R_5iNTkLqxP6ZbD7H  0.071655  0.104923
# 2     1+90 Years Crafting.mp4  R_x5FWpiRdYvqrumZ  0.069265  0.068579
# 3     1+90 Years Crafting.mp4  R_2WDsrmAlPtoO0HZ  0.085395  0.055002
# 4     1+90 Years Crafting.mp4  R_2DTAqyIUDqXnKfP  0.069290  0.087720
# 5     1+90 Years Crafting.mp4  R_1Ic2grCw4d162ym  0.055206  0.093040
# 6     1+90 Years Crafting.mp4  R_ysdra57Iv3uoFm9  0.106843  0.143136
# 7     1+90 Years Crafting.mp4  R_pcjQCK9dAmqufrX  0.055028  0.104855
# 8     1+90 Years Crafting.mp4  R_2V3B9AvjeLjviju  0.113406  0.120954
# 9  10+Aptamil Advert 2021.mp4  R_2cjymW7g7GFnOaL  0.084050  0.083635
#
#    combined_std  convex_hull_area  convex_hull_area_shapely  \
# 0      0.141550          0.067034                  0.067034
# 1      0.127056          0.063680                  0.063680
# 2      0.097471          0.040371                  0.040371
# 3      0.101575          0.051600                  0.051600
# 4      0.111785          0.053018                  0.053018
# 5      0.108186          0.040562                  0.040562
# 6      0.178615          0.133560                  0.133560
# 7      0.118417          0.063625                  0.063625
# 8      0.165804          0.130167                  0.130167
# 9      0.118571          0.082235                  0.082235
#
#    mean_euclidean_distance
# 0                 0.114140
# 1                 0.112329
# 2                 0.084495
# 3                 0.083171
# 4                 0.097591
# 5                 0.094437
# 6                 0.153353
# 7                 0.099924
# 8                 0.142750
# 9                 0.101962
#
# [10 rows x 82 columns]

# %%
len(data)
# Out:
# 746

# %%
data = data.dropna()

# %%
len(data)
# Out:
# 746

# %% [markdown]
# # PCA

# %%
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = data[features]
y = data['convex_hull_area']

# Standardize your features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

# %%
# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Get explained variance ratios
explained_var_ratio = pca.explained_variance_ratio_

# Determine number of components to keep
total_var = 0
n_components = 0
for i, ratio in enumerate(explained_var_ratio):
    total_var += ratio
    if total_var >= 0.975:  # Adjust the threshold as needed
        n_components = i + 1
        break

print(f"Number of principal components selected: {n_components}")

# Apply PCA transformation with selected components
pca_final = PCA(n_components=n_components)
X_selected = pca_final.fit_transform(X_scaled)

# Get selected features (if needed, you can interpret the components to understand which original features contribute the most)
selected_features = X.columns[pca_final.components_.mean(axis=0).argsort()[::-1][:n_components]]
print("Selected features by PCA:", selected_features)
# Out:
# Number of principal components selected: 33
# Selected features by PCA: Index(['mfcc_11_mean', 'mel_spectrogram_mean', 'mel_spectrogram_std',
#        'pitch_mean', 'mfcc_13_mean', 'mfcc_6_std', 'spectral_bandwidth_std',
#        'pitch_std', 'chroma_9_std', 'mfcc_4_mean', 'mfcc_9_mean', 'rms_max',
#        'rms_mean', 'chroma_10_mean', 'zcr_mean', 'mfcc_12_mean', 'mfcc_1_std',
#        'chroma_9_mean', 'spectral_bandwidth_mean', 'chroma_7_std',
#        'spectral_centroid_mean', 'mfcc_10_mean', 'mfcc_2_std', 'mfcc_3_mean',
#        'chroma_4_mean', 'chroma_5_mean', 'rms_std', 'mfcc_7_mean',
#        'mfcc_3_std', 'chroma_11_mean', 'mfcc_12_std', 'mfcc_8_std',
#        'mfcc_7_std'],
#       dtype='object')

# %%
sorted_values = np.sort(selected_features.values)
sorted_values
# Out:
# array(['chroma_10_mean', 'chroma_11_mean', 'chroma_4_mean',
#        'chroma_5_mean', 'chroma_7_std', 'chroma_9_mean', 'chroma_9_std',
#        'mel_spectrogram_mean', 'mel_spectrogram_std', 'mfcc_10_mean',
#        'mfcc_11_mean', 'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean',
#        'mfcc_1_std', 'mfcc_2_std', 'mfcc_3_mean', 'mfcc_3_std',
#        'mfcc_4_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std',
#        'mfcc_8_std', 'mfcc_9_mean', 'pitch_mean', 'pitch_std', 'rms_max',
#        'rms_mean', 'rms_std', 'spectral_bandwidth_mean',
#        'spectral_bandwidth_std', 'spectral_centroid_mean', 'zcr_mean'],
#       dtype=object)

# %%
len(sorted_values)
# Out:
# 33

# %%
data['preference'] = data['GroupN(1=low(1-3),2=neutral(4-6),3=high(7-10))']

# %%
conditions = [
    (0 < data['PurchaseDesireMean']) & (data['PurchaseDesireMean'] <= 3),
    (3 < data['PurchaseDesireMean']) & (data['PurchaseDesireMean'] <= 6),
    (6 < data['PurchaseDesireMean']) & (data['PurchaseDesireMean'] <= 10)
]

choices = [1, 2, 3]

data['purchase'] = np.select(conditions, choices)

# %% [raw]
# data.to_csv('infant_ads_variables_audio06292024.csv', index=False)

# %%
data.columns
# Out:
# Index(['filename', 'duration', 'rms_mean', 'rms_std', 'rms_max', 'zcr_mean',
#        'zcr_std', 'spectral_centroid_mean', 'spectral_centroid_std',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_std', 'pitch_mean',
#        'pitch_std', 'mfcc_1_mean', 'mfcc_1_std', 'mfcc_2_mean', 'mfcc_2_std',
#        'mfcc_3_mean', 'mfcc_3_std', 'mfcc_4_mean', 'mfcc_4_std', 'mfcc_5_mean',
#        'mfcc_5_std', 'mfcc_6_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std',
#        'mfcc_8_mean', 'mfcc_8_std', 'mfcc_9_mean', 'mfcc_9_std',
#        'mfcc_10_mean', 'mfcc_10_std', 'mfcc_11_mean', 'mfcc_11_std',
#        'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean', 'mfcc_13_std',
#        'chroma_1_mean', 'chroma_1_std', 'chroma_2_mean', 'chroma_2_std',
#        'chroma_3_mean', 'chroma_3_std', 'chroma_4_mean', 'chroma_4_std',
#        'chroma_5_mean', 'chroma_5_std', 'chroma_6_mean', 'chroma_6_std',
#        'chroma_7_mean', 'chroma_7_std', 'chroma_8_mean', 'chroma_8_std',
#        'chroma_9_mean', 'chroma_9_std', 'chroma_10_mean', 'chroma_10_std',
#        'chroma_11_mean', 'chroma_11_std', 'chroma_12_mean', 'chroma_12_std',
#        'mel_spectrogram_mean', 'mel_spectrogram_std', 'VideoNumber',
#        'GroupN(1=low(1-3),2=neutral(4-6),3=high(7-10))', 'PrefereneMean',
#        'PurchaseDesireMean', 'NarrativeInterityMean', 'EmpathyMean',
#        'TotalTime(S)', 'ShotNumber', 'ShotMean', 'ad_id', 'id', 'std_x',
#        'std_y', 'combined_std', 'convex_hull_area', 'mean_euclidean_distance',
#        'intercept', 'preference', 'purchase'],
#       dtype='object')

# %%
data.head()
# Out:
#                   filename   duration  rms_mean   rms_std   rms_max  zcr_mean  \
# 0  1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023   0.06758
# 1  1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023   0.06758
# 2  1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023   0.06758
# 3  1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023   0.06758
# 4  1+90 Years Crafting.mp3  32.299977  0.067268  0.042547  0.186023   0.06758
#
#     zcr_std  spectral_centroid_mean  spectral_centroid_std  \
# 0  0.083763             3061.162958            2014.217722
# 1  0.083763             3061.162958            2014.217722
# 2  0.083763             3061.162958            2014.217722
# 3  0.083763             3061.162958            2014.217722
# 4  0.083763             3061.162958            2014.217722
#
#    spectral_bandwidth_mean  ...                    ad_id                 id  \
# 0              3452.305987  ...  1+90 Years Crafting.mp4  R_2qFdJq0jnOo6gpt
# 1              3452.305987  ...  1+90 Years Crafting.mp4  R_5iNTkLqxP6ZbD7H
# 2              3452.305987  ...  1+90 Years Crafting.mp4  R_x5FWpiRdYvqrumZ
# 3              3452.305987  ...  1+90 Years Crafting.mp4  R_2WDsrmAlPtoO0HZ
# 4              3452.305987  ...  1+90 Years Crafting.mp4  R_2DTAqyIUDqXnKfP
#
#       std_x     std_y  combined_std  convex_hull_area  \
# 0  0.049059  0.132776      0.141550          1.166466
# 1  0.071655  0.104923      0.127056          1.013764
# 2  0.069265  0.068579      0.097471          0.889882
# 3  0.085395  0.055002      0.101575          0.960789
# 4  0.069290  0.087720      0.111785          0.951930
#
#    mean_euclidean_distance  intercept  preference  purchase
# 0                 0.114140          1           2         2
# 1                 0.112329          1           2         2
# 2                 0.084495          1           2         2
# 3                 0.083171          1           2         2
# 4                 0.097591          1           2         2
#
# [5 rows x 84 columns]

# %%
data.tail()
# Out:
#                                               filename  duration  rms_mean  \
# 653  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
# 654  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
# 655  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
# 656  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
# 657  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...     58.45  0.048806
#
#      rms_std   rms_max  zcr_mean   zcr_std  spectral_centroid_mean  \
# 653  0.03088  0.157743  0.033685  0.021835             1380.853342
# 654  0.03088  0.157743  0.033685  0.021835             1380.853342
# 655  0.03088  0.157743  0.033685  0.021835             1380.853342
# 656  0.03088  0.157743  0.033685  0.021835             1380.853342
# 657  0.03088  0.157743  0.033685  0.021835             1380.853342
#
#      spectral_centroid_std  spectral_bandwidth_mean  ...  \
# 653             525.336408              1634.023818  ...
# 654             525.336408              1634.023818  ...
# 655             525.336408              1634.023818  ...
# 656             525.336408              1634.023818  ...
# 657             525.336408              1634.023818  ...
#
#                                                  ad_id                 id  \
# 653  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...  R_pcjQCK9dAmqufrX
# 654  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...  R_3QVndydHS3ggukh
# 655  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...  R_3n75JGLz1DIwqsc
# 656  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...  R_W3A7gkKqFyYxn5D
# 657  99+VINTAGE 1958 PET EVAPORATED MILK COMMERCIAL...  R_2Xps7uqZpYygTm6
#
#         std_x     std_y  combined_std  convex_hull_area  \
# 653  0.061889  0.095416      0.113730          0.878797
# 654  0.072965  0.084651      0.111757          0.959388
# 655  0.072944  0.091150      0.116744          1.030377
# 656  0.042931  0.063930      0.077007          0.576954
# 657  0.067836  0.068460      0.096376          0.854313
#
#      mean_euclidean_distance  intercept  preference  purchase
# 653                 0.104958          1           2         2
# 654                 0.101739          1           2         2
# 655                 0.103575          1           2         2
# 656                 0.069639          1           2         2
# 657                 0.083729          1           2         2
#
# [5 rows x 84 columns]
